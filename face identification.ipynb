# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

img1 = cv.imread("120120_faces.jpg",cv.IMREAD_GRAYSCALE) # queryImage

img2 = cv.imread("323323_faces.jpg",cv.IMREAD_GRAYSCALE) # trainImage

# Initiate SIFT detector
sift = cv.xfeatures2d.SIFT_create(nfeatures =1000,
nOctaveLayers = 3,
contrastThreshold = 0.04,
edgeThreshold = 10,
sigma = 1.6)
# find the keypoints and descriptors with SIFT
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)
# BFMatcher with default params
bf = cv.BFMatcher()
matches = bf.knnMatch(des1,des2,k=2)
# Apply ratio test
good = []
for m,n in matches:
    if m.distance >0.90*n.distance:
        good.append([m])
# cv.drawMatchesKnn expects list of lists as matches.
img3 = cv.drawMatchesKnn(img1,kp1,img2,kp2,good,None,flags=cv.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)

# %% [markdown]
# # Uploaded image of low Brightness

# %%
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x11a5b5810>, None)

# %%
if len(good) > 500:
    print("matched")
else:
    print("mismatched")
# Out:
# mismatched

# %% [markdown]
# issue if not working library opencv
#
# https://stackoverflow.com/questions/52305578/sift-cv2-xfeatures2d-sift-create-not-working-even-though-have-contrib-instal
